# %% [markdown]
# <a href="https://colab.research.google.com/github/shriyaai/first_repo/blob/main/program3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
employee={"name":"Shriya","age":45,"salary":26000,"company":"wipro"}
print(type(employee))
print("printing employee data...")
print(employee)
# Out:
# <class 'dict'>
# printing employee data...
# {'name': 'Shriya', 'age': 45, 'salary': 26000, 'company': 'wipro'}

# %%
my_dict = {4: 'shriya', 2: 'sarmi'}
print("\nDictionary with each item:")
print(my_dict)
# Out:
# Dictionary with each item:
# {4: 'shriya', 2: 'sarmi'}

# %%
my_dict = {4: 'shriya', 2: 'sarmi'}
print("\nDictionary with each item:")
print(my_dict)
# Out:
# Dictionary with each item:
# {4: 'shriya', 2: 'sarmi'}

# %%
my_dict[0]="riya"
my_dict[3]="ram"
print(my_dict)
# Out:
# {4: 'shriya', 2: 'sarmi', 0: 'riya', 3: 'ram'}

# %%
employee["age"]=30,70,39
print(employee)
# Out:
# {'name': 'Shriya', 'age': (30, 70, 39), 'salary': 26000, 'company': 'wipro'}

# %%
employee["name"] = input("name:");
employee["age"]=input("age:");
employee["salary"]=input("salary:");
print(employee)
# Out:
# name:raj
# age:32
# salary:66700
# {'name': 'raj', 'age': '32', 'salary': '66700', 'company': 'wipro'}

# %%
Pop = employee.pop("age")
print(employee)
# Out:
# {'name': 'raj', 'salary': '66700'}

# %%
for x in employee:
  print(employee[x])
# Out:
# raj
# 66700

# %%
for x in employee.values():
  print(x)
# Out:
# raj
# 66700

# %%
days ={"mon","tue","wed","thur","fri"}
print(days)
print(type(days))
for i in days:
      print(i)
# Out:
# {'tue', 'fri', 'mon', 'thur', 'wed'}
# <class 'set'>
# tue
# fri
# mon
# thur
# wed

# %%
set = {1,2,3,"java",5,6}
print(type(set))
# Out:
# <class 'set'>

# %%
set1={}
print(type(set1))
# Out:
# <class 'dict'>

# %%
days.add("sun")
print(days)
# Out:
# {'tue', 'fri', 'sun', 'mon', 'thur', 'wed'}

# %%
for i in days:
  print(i)
# Out:
# tue
# fri
# sun
# mon
# thur
# wed

# %%
days.update(["monday","tuesday"]);
print(days)
# Out:
# {'tue', 'fri', 'sun', 'mon', 'thur', 'tuesday', 'wed', 'monday'}

# %%
days.discard("wed");
print(days)
# Out:
# {'tue', 'fri', 'sun', 'mon', 'thur', 'tuesday', 'monday'}

# %%
for i in days:
  print(i)
# Out:
# tue
# fri
# sun
# mon
# thur
# tuesday
# monday

# %%
days.remove("fri");
print(days)
# Out:
# {'tue', 'sun', 'mon', 'thur', 'tuesday', 'monday'}

# %%
days.pop();
print(days)
# Out:
# {'sun', 'mon', 'thur', 'tuesday', 'monday'}

# %%
month = {"jan","feb","mar","apr","may",}
month2 = {"jun","jul","aug","sep","oct","nov","dec"}
print(month|month2)
# Out:
# {'feb', 'may', 'jul', 'jan', 'mar', 'sep', 'nov', 'apr', 'jun', 'dec', 'oct', 'aug'}

# %%
print(month.union(month2))
# Out:
# {'feb', 'may', 'jul', 'jan', 'mar', 'sep', 'nov', 'apr', 'jun', 'dec', 'oct', 'aug'}

# %%
month3 = {"jun","jul","aug","sep","oct","nov","dec"}
month.union(month2,month3)
# Out:
# {'apr',
#  'aug',
#  'dec',
#  'feb',
#  'jan',
#  'jul',
#  'jun',
#  'mar',
#  'may',
#  'nov',
#  'oct',
#  'sep'}

# %%
print(month2&month3)
# Out:
# {'jul', 'sep', 'nov', 'jun', 'dec', 'oct', 'aug'}

# %%
print(month2.intersection(month3))
# Out:
# {'jul', 'sep', 'nov', 'jun', 'dec', 'oct', 'aug'}

# %%
month2.intersection_update(month3)
print(month2)
# Out:
# {'jul', 'sep', 'nov', 'jun', 'dec', 'oct', 'aug'}

# %%
month = {"jan","feb","mar","apr","may"}
month2 = {"sep","oct","nov","dec"}
month3 = {"jun","jul","aug","sep"}
common = month3.intersection(month,month2)
print(common)
# Out:
# set()

# %%
month = {"jan","feb","mar","apr","may"}
month2 = {"sep","oct","nov","dec"}
month3 = {"jun","jul","aug","sep"}
print(month3-month2)
# Out:
# {'jun', 'aug', 'jul'}

# %%
print(month3.difference(month2))
# Out:
# {'jun', 'aug', 'jul'}

# %%
a = month^month2
print(a)
# Out:
# {'feb', 'may', 'jan', 'mar', 'sep', 'nov', 'apr', 'dec', 'oct'}

# %%
month3=a.symmetric_difference(month2)
print(month3)
# Out:
# {'feb', 'may', 'jan', 'mar', 'apr'}

# %%
print(month>month2)
print(month3 == month)
print(month2<month3)
# Out:
# False
# True
# False

# %%
month.add("wed")
print(month)
# Out:
# {'feb', 'apr', 'may', 'wed', 'jan', 'mar'}

# %%
def square(num):
  return num*num
print(square(5))
# Out:
# 25

# %%
def square( item_list ):
  squares = [ ]
  for l in item_list:
    squares.append( l**2 )
  return squares

# %%
add=lambda num:num+4
print(add(6))
# Out:
# 10

# %%
def add(num):
  return num+4
print(add(6))
# Out:
# 10

# %%
def fact(num):
  if num==1:
    return 1
  else:
    return num*fact(num-1)
