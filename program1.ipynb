# %% [markdown]
# <a href="https://colab.research.google.com/github/shriyaai/first_repo/blob/main/program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import cv2

# %%
img=cv2.imread("/content/butter.jpg")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d0027ef4e25a> in <cell line: 1>()
# ----> 1 cv2_imshow(img)
#
# NameError: name 'cv2_imshow' is not defined

# %%
import numpy as np

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=2697x4061>

# %%
img=cv2.imread("/content/butter.jpg",0)

# %%
cv2.imwrite('save_img.png',img)
# Out:
# True
