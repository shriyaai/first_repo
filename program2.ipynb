# %% [markdown]
# <a href="https://colab.research.google.com/github/shriyaai/first_repo/blob/main/program2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
pattern = "cat"
a=input("enter a string:")
if re.match(pattern,a):
    print("match")
else:
    print("not match")
# Out:
# enter a string:cat
# match

# %%
import re
pattern = "cat|dog"
a = input("Enter a string:")
if re.match(pattern,a):
    print("match")
else:
    print("not match")
# Out:
# Enter a string:gog
# not match

# %%
import re
pattern="\d"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-718131657.py:2: SyntaxWarning: invalid escape sequence '\d'
#   pattern="\d"
# enter a string7
# match

# %%
import re
pattern="[a-z]"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# enter a stringh
# match

# %%
import re
pattern="[A-Z]"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# enter a stringg
# not match

# %%
import re
pattern="\d{4}"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-3965866564.py:2: SyntaxWarning: invalid escape sequence '\d'
#   pattern="\d{4}"
# enter a string3456
# match

# %%
import re
pattern="\d{4,}"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-2322477430.py:2: SyntaxWarning: invalid escape sequence '\d'
#   pattern="\d{4,}"
# enter a string237357
# match

# %%
import re
pattern="\d*"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-310093079.py:2: SyntaxWarning: invalid escape sequence '\d'
#   pattern="\d*"
# enter a string7676
# match

# %%
import re
pattern="[a-z]{4}"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# enter a stringfig
# not match

# %%
import re
pattern="\w{6,12}"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipython-input-1733203207.py:2: SyntaxWarning: invalid escape sequence '\w'
#   pattern="\w{6,12}"
# enter a stringshhdhhj
# match

# %%
import re
pattern="[aeiouAEIOU]"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# enter a stringAPPLE
# match

# %%
import re
pattern="[^aeiouAEIOU\W\d]"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\W'
# <>:2: SyntaxWarning: invalid escape sequence '\W'
# /tmp/ipython-input-1846986388.py:2: SyntaxWarning: invalid escape sequence '\W'
#   pattern="[^aeiouAEIOU\W\d]"
# enter a stringkljhgfd
# match

# %%
import re
pattern="[a-zA-Z0-9]"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# enter a stringhh
# match

# %%
import re
pattern="[^a-zA-Z0-9]"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# enter a string&
# match

# %%
import re
pattern="\D"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipython-input-3146526473.py:2: SyntaxWarning: invalid escape sequence '\D'
#   pattern="\D"
# enter a string56
# not match

# %%
import re
pattern="^A.*"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# enter a stringA123
# match

# %%
import re
pattern=".*Z$"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# enter a stringhfhfZ
# match

# %%
import re
pattern="^(\d).*\1$"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-465336076.py:2: SyntaxWarning: invalid escape sequence '\d'
#   pattern="^(\d).*\1$"
# enter a string567845
# not match

# %%
import re
pattern="^\d{10}$"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-452043920.py:2: SyntaxWarning: invalid escape sequence '\d'
#   pattern="^\d{10}$"
# enter a string098765432122
# not match

# %%
import re
pattern="^[a-zA-Z0-9._]+@[a-zA-Z]+\.[a-zA-Z]{2,}$"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipython-input-1283432016.py:2: SyntaxWarning: invalid escape sequence '\.'
#   pattern="^[a-zA-Z0-9._]+@[a-zA-Z]+\.[a-zA-Z]{2,}$"
# enter a stringdffgh@dffg.com
# match

# %%
import re
pattern="^\d{2}-\d{2}-\d{4}$"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-3573386670.py:2: SyntaxWarning: invalid escape sequence '\d'
#   pattern="^\d{2}-\d{2}-\d{4}$"
# enter a string24-06-2006
# match

# %%
import re
pattern="^[a-zA-Z0-9]+$"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# enter a stringdhgf456h
# match

# %%
import re
pattern="^[a-zA-Z][a-zA-Z0-9]*$"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# enter a stringhgf567jkl
# match

# %%
import re
pattern="\s+"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-1399877326.py:2: SyntaxWarning: invalid escape sequence '\s'
#   pattern="\s+"
# enter a string4656
# not match

# %%
import re
pattern="\w+(?:\s+\w+)+"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipython-input-1984437200.py:2: SyntaxWarning: invalid escape sequence '\w'
#   pattern="\w+(?:\s+\w+)+"
# enter a stringhjk 897
# match

# %%
import re
pattern="^\w+"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipython-input-2446658079.py:2: SyntaxWarning: invalid escape sequence '\w'
#   pattern="^\w+"
# enter a stringeed 454
# match

# %%
import re
pattern="\w+$"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipython-input-3319024522.py:2: SyntaxWarning: invalid escape sequence '\w'
#   pattern="\w+$"
# enter a stringihddh hgh
# not match

# %%
import re
pattern="\b\w+\b"
a = input("enter a string")
if re.match(pattern,a):
  print("match")
else:
  print("not match")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipython-input-1449063486.py:2: SyntaxWarning: invalid escape sequence '\w'
#   pattern="\b\w+\b"
# enter a stringghj mkl
# not match
