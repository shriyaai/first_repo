# %% [markdown]
# <a href="https://colab.research.google.com/github/shriyaai/first_repo/blob/main/program7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
number = int(input("Enter a number: "))

if number % 2 == 0:
    print(f"{number} is an even number.")
else:
    print(f"{number} is an odd number.")
# Out:
# Hello, World!
# Enter a number: 34
# 34 is an even number.

# %%
n=int(input("enter a numbers:"))
sum=0
for i in range (1,n+1):
    sum+=i
print(sum)
# Out:
# enter a numbers:5
# 15

# %%
n=int(input("enter a number:"))
sum=n*(n+1)//2
print(sum)
# Out:
# enter a number:5
# 15

# %%
n=int(input("enter number of numbers to be added:"))
sum =0
for i in range(n):
  num=int(input(f"enter number{i+1}"))
  sum+=num
  print(sum)
# Out:
# enter number of numbers to be added:4
# enter number112
# 12
# enter number234
# 46
# enter number365
# 111
# enter number434
# 145

# %%
n = int(input("enter the number"))
factorial=1
for i in range(1,n+1):
  factorial*=i
print(factorial)
# Out:
# enter the number4
# 24

# %%
n=int(input("enter a number:"))
for i in range(1, n + 1):
    print(" " * (n - i), end="")
    print("*" * (2 * i - 1))
# Out:
# enter a number:5
#     *
#    ***
#   *****
#  *******
# *********

# %%
string = input("enter a string:")
length=0
for char in string:
  length+=1
print(length)
# Out:
# enter a string:sarmini
# 7

# %%
string = input("enter a string:")
if string == string[::-1]:
  print("palimdrome")
else:
  print("not palindrome")
# Out:
# enter a string:shriya
# not palindrome
