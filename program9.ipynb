# %% [markdown]
# <a href="https://colab.research.google.com/github/shriyaai/first_repo/blob/main/program9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class BankAccount:
  def __init__(self,account_holder,initial_balance):
    self.account_holder = account_holder
    self.__balance = initial_balance
  def deposite(self,amount):
    self.__balance += amount
    return self.__balance
  def withdraw(self,amount):
    if amount <= self.__balance:
      self.__balance -= amount
      return self.__balance
    else:
      return "insufficient balance"
  def get_balance(self):
    return self.__balance
class SavingsAccount(BankAccount):
  def __init__(self,account_holder,initial_balance,interest_rate):
    super().__init__(account_holder,initial_balance)
    self.interest_rate = interest_rate
    super().withraw(amount)
  def add_interest(self):
    interest = self.interest_rate * self.get_balance()
    self.deposite(interest)
    return self.get_balance()
account1 = BankAccount("Raj",1000)
account1.deposite(500)
account1.withdraw(200)
print(account1.get_balance())
account2 = SavingsAccount("Ram",1000,0.05)
account2.add_interest()
savings.deposite(500)
savings.withdraw(200)
print(savings.get_balance())
# Out:
# 1300
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2295576647.py in <cell line: 0>()
#      27 account1.withdraw(200)
#      28 print(account1.get_balance())
# ---> 29 account2 = SavingsAccount("Ram",1000,0.05)
#      30 account2.add_interest()
#      31 savings.deposite(500)
#
# /tmp/ipython-input-2295576647.py in __init__(self, account_holder, initial_balance, interest_rate)
#      18     super().__init__(account_holder,initial_balance)
#      19     self.interest_rate = interest_rate
# ---> 20     super().withraw(amount)
#      21   def add_interest(self):
#      22     interest = self.interest_rate * self.get_balance()
#
# AttributeError: 'super' object has no attribute 'withraw'

# %%
class BankAccount:
    def __init__(self, account_holder, initial_balance):
        self.account_holder = account_holder
        self.__balance = initial_balance
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"₹{amount} deposited. Updated balance: ₹{self.__balance}")
        else:
            print("Deposit amount must be positive.")
    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
            print(f"₹{amount} withdrawn. Remaining balance: ₹{self.__balance}")
        else:
            print("Insufficient balance!")
    def get_balance(self):
        return self.__balance
class SavingsAccount(BankAccount):
    def __init__(self, account_holder, initial_balance, interest_rate):
        super().__init__(account_holder, initial_balance)
        self.interest_rate = interest_rate
    def withdraw(self, amount):
        if amount > 20000:
            print("Withdrawal limit exceeded! Maximum ₹20,000 per transaction.")
        else:
            super().withdraw(amount)
    def add_interest(self):
        interest = self.get_balance() * (self.interest_rate / 100)
        self.deposit(interest)
        print(f"Interest of ₹{interest} added at {self.interest_rate}% rate.")

print("----- BankAccount Testing -----")
account1 = BankAccount("Rahul", 50000)
account1.deposit(10000)
account1.withdraw(20000)
print(f"Final Balance: ₹{account1.get_balance()}")

print("\n----- SavingsAccount Testing -----")
account2 = SavingsAccount("Anita", 80000, 5)
account2.deposit(5000)
account2.withdraw(25000)
account2.withdraw(15000)
account2.add_interest()
print(f"Final Balance: ₹{account2.get_balance()}")
# Out:
# ----- BankAccount Testing -----
# ₹10000 deposited. Updated balance: ₹60000
# ₹20000 withdrawn. Remaining balance: ₹40000
# Final Balance: ₹40000
#
# ----- SavingsAccount Testing -----
# ₹5000 deposited. Updated balance: ₹85000
# Withdrawal limit exceeded! Maximum ₹20,000 per transaction.
# ₹15000 withdrawn. Remaining balance: ₹70000
# ₹3500.0 deposited. Updated balance: ₹73500.0
# Interest of ₹3500.0 added at 5% rate.
# Final Balance: ₹73500.0
